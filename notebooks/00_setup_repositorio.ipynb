# %% [markdown]
# # 🚀 Setup do Repositório + Versionamento no Google Colab
#
# **Desafio Alura + Oracle — Agente Corporativo de IA**
#
# Este notebook conecta o Google Colab ao seu repositório GitHub e permite fazer commits/push direto daqui.
#
# > ⚠️ **Nunca** deixe seu token (PAT) exposto no código publicado. Use `getpass` como abaixo.

# %% [markdown]
# ## 1. Verificar versão do Git e Python

# %%
# !git --version
# !python --version

# %% [markdown]
# ## 2. Configurar sua identidade no Git
# Ajuste com seu nome e e-mail do GitHub.

# %%
# !git config --global user.name "Orlando Caetano"
# !git config --global user.email "seu-email@exemplo.com"

# %% [markdown]
# ## 3. Autenticação segura (Personal Access Token)
# Gere um token em: GitHub → Settings → Developer settings → Personal access tokens → Tokens (classic) → escopo `repo`.
#
# O `getpass` esconde o token na tela.

# %%
from getpass import getpass

usuario = "OrlandoCaetano2026"
token = getpass('Cole seu GitHub Token (PAT): ')
repo = "agente-corporativo"
url = f"https://{usuario}:{token}@github.com/{usuario}/{repo}.git"

# %% [markdown]
# ## 4. Clonar o repositório

# %%
# !git clone {url}
# %cd {repo}
# !ls -la

# %% [markdown]
# ## 5. Fazer alterações e enviar (commit + push)
# Depois de editar/criar arquivos, rode esta célula para versionar.

# %%
# !git add .
# !git commit -m "Passo 1: estrutura inicial do projeto"
# !git push origin main

# %% [markdown]
# ## 6. Puxar atualizações (quando editar no GitHub/outro lugar)

# %%
# !git pull origin main
